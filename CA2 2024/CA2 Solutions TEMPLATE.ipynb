# %% [markdown]
# # Problem 1: Classification

# %% [markdown]
# (1a)

# %% [markdown]
# (1b)

# %% [markdown]
# (1c)

# %% [markdown]
# (1d)

# %% [markdown]
# (1e)

# %% [markdown]
# (1f)

# %% [markdown]
# (1g)

# %% [markdown]
# # Problem 2: Clustering

# %% [markdown]
# (2a)

# %% [markdown]
# (2b)

# %% [markdown]
# (2c)

# %% [markdown]
# (2d)

# %% [markdown]
# # Problem 3: Neural Networks

# %% [markdown]
# (3a)

# %% [markdown]
# (3b)

# %% [markdown]
# (3c)
